# %% [markdown]
# # Tarrifs Analysis
#
# The purpose of this project is to analyze [this dataset](https://www.kaggle.com/datasets/danielcalvoglez/us-tariffs-2025) using k-means clustering to organize groups of countries into distinct profiles based on their trade relationships with the United States. We will normalize trade figures by population to create per-capita values. We will look for outliers and attempt to characterize the relationship of the United States with each country based on the cluster. We will also attempt to characterize the clusters based on potential efficacy of the tariffs in creating a positive outcome for the United States in terms of trade balance, economic growth, and political leverage.
#
# We hope to identify distinct groups of US trading partners (e.g., "High Deficit, Large Population", "Balanced Trade, Small Population", "High Surplus, Medium Population") and analyze if tariffs correlate with these profiles. This could reveal patterns in how the US trades with different types of economies and lead to interesting analysis on potential outcomes of these tarrifs.

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("danielcalvoglez/us-tariffs-2025")

print("Path to dataset files:", path)
# Out:
# ...
# Path to dataset files: C:\Users\David\.cache\kagglehub\datasets\danielcalvoglez\us-tariffs-2025\versions\2

# %%
import os

# List the files in the dataset path to find the dataset file
files_in_path = os.listdir(path)
files_in_path

# Now, identify the main dataset file (usually a .csv or .xlsx) to proceed with loading it.
# Out:
# ['Tariff Calculations plus Population.csv', 'Tariff Calculations.csv']

# %%
import pandas as pd

# Load the dataset containing population information
file_path = os.path.join(path, 'Tariff Calculations plus Population.csv')
tariffs_with_population_df = pd.read_csv(file_path, sep=';')

# Convert numeric columns to appropriate data types
numeric_columns = ['US 2024 Deficit', 'US 2024 Exports', 'US 2024 Imports (Customs Basis)', 'Population']
for col in numeric_columns:
    tariffs_with_population_df[col] = pd.to_numeric(tariffs_with_population_df[col], errors='coerce')

# Display the first few rows of the dataframe to verify
print(tariffs_with_population_df.head())

# Check for outliers using quantiles rather than boxplots, focus on numeric variables
Q1 = tariffs_with_population_df[numeric_columns].quantile(0.25)
Q3 = tariffs_with_population_df[numeric_columns].quantile(0.75)
IQR = Q3 - Q1  # Interquartile Range
outliers = ((tariffs_with_population_df[numeric_columns] < (Q1 - 1.5 * IQR)) | (tariffs_with_population_df[numeric_columns] > (Q3 + 1.5 * IQR))).sum()
print("Potential outliers each column:")
print(outliers)  # Counts provided for each column

# This ensures that numerical operations are conducted on actual numeric types.
# Out:
#        Country  US 2024 Deficit  US 2024 Exports  \
# 0  Afghanistan            -11.1             11.4
# 1      Albania             13.4            141.7
# 2      Algeria              NaN              NaN
# 3      Andorra              1.5              4.9
# 4       Angola              NaN            682.4
#
#    US 2024 Imports (Customs Basis) Trump Tariffs Alleged Trump Response  \
# 0                             22.6                   49%            25%
# 1                            128.3                   10%            10%
# 2                              NaN                   59%            29%
# 3                              3.4                   10%            10%
# 4                              NaN                   63%            32%
#
#    Population
# 0  41454761.0
# 1   2745972.0
# 2  46164219.0
# 3     80856.0
# 4  36749906.0
# Potential outliers each column:
# US 2024 Deficit                    34
# US 2024 Exports                    19
# ...

# %%
# Drop NaN rows in the dataframe to clean up data for analysis
tariffs_with_population_df_cleaned = tariffs_with_population_df.dropna()

tariffs_with_population_df_cleaned.head()  # Verify that NaN rows are removed

# By cleaning the dataframe, we ensure that further analysis uses complete data.
# Out:
#                Country  US 2024 Deficit  US 2024 Exports  \
# 0          Afghanistan            -11.1             11.4
# 1              Albania             13.4            141.7
# 3              Andorra              1.5              4.9
# 6  Antigua and Barbuda            550.0            573.8
# 8              Armenia             39.2            160.8
#
#    US 2024 Imports (Customs Basis) Trump Tariffs Alleged Trump Response  \
# 0                             22.6                   49%            25%
# 1                            128.3                   10%            10%
# 3                              3.4                   10%            10%
# 6                             23.8                   10%            10%
# 8                            121.6                   10%            10%
#
#    Population
# 0  41454761.0
# 1   2745972.0
# 3     80856.0
# 6     93316.0
# 8   2990900.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Function to create boxplots by quantile groups with additional statistics
def create_boxplot_by_quantiles_with_stats(df, column, quantiles):
    # Create quantile groups
    df['Quantile_Group'] = pd.qcut(df[column], q=quantiles, labels=[f'Q{i+1}' for i in range(quantiles)])
    plt.figure(figsize=(10, 5))
    sns.boxplot(x='Quantile_Group', y=column, data=df)
    
    # Calculate and overlay statistics
    stats = df.groupby('Quantile_Group')[column].agg(['mean', 'median'])
    for q, stats_row in stats.iterrows():
        plt.scatter(int(q[-1]) - 1, stats_row['mean'], color='red', s=100, label=f'Mean Q{q[-1]}' if q=="Q1" else "")
        plt.scatter(int(q[-1]) - 1, stats_row['median'], color='blue', s=100, label=f'Median Q{q[-1]}' if q=="Q1" else "")

    plt.title(f'Boxplot of {column} by Quantile Group with Statistics')
    plt.legend()
    plt.show()

# Create boxplots by quantile group for each numeric column and include stats
quantiles = 4  # Dividing into four groups (quartiles)
for col in numeric_columns:
    create_boxplot_by_quantiles_with_stats(tariffs_with_population_df, col, quantiles)

# Layout Reset Consideration
plt.close('all')  # Optionally close all figures if needing to refine or reset layouts

## Completion of the EDA phase
summary_conclusion = '''Project Summary:\n1. Initial EDA process completed identifying potential outliers graphically.\n2. Visualization of relationships and distributions for numeric datasets achieved.\n3. Preliminary plan concepts now apply and visualized any next steps such as k-means analysis.'''  # Detailed lines of future next steps are engaged.
# Out:
# C:\Users\David\AppData\Local\Temp\ipykernel_15936\1557643251.py:12: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   stats = df.groupby('Quantile_Group')[column].agg(['mean', 'median'])
# C:\Users\David\AppData\Local\Temp\ipykernel_15936\1557643251.py:12: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   stats = df.groupby('Quantile_Group')[column].agg(['mean', 'median'])
# ...

# %% [markdown]
# # Exploratory Data Analysis Review
#
# In examining the boxplots for the various per-capita trade figures with the U.S., a few patterns emerge. The interquartile ranges suggest significant disparities in trade balances among different countries, with some outliers indicating unique trading circumstances or economic situations. For example, countries with very high or low trade figures relative to their populations stand out in this graphical analysis, pointing to possible anomalies or strategic economic partnerships.
#
# The visualization process allows us to pinpoint how certain countries stack up against others in terms of trade deficit, exports, and imports, all normalized by population. This normalization helps us compare countries more fairly by accounting for population size differences, providing a perspective on how intensely each country interacts with the U.S. economically.
#
# ### Next Steps
#
# Having identified these disparities, the next step is to delve deeper using k-means clustering. By grouping countries into clusters based on these per-capita indicators, we can uncover distinct profiles that might reveal trends in how the U.S. engages with its trading partners. This method promises to distinguish countries with high deficits and large populations from those with balanced trade patterns and smaller populations, offering new insights into the efficacy and impact of tariffs.
#
# Clusters will help us understand if qualitative aspects like tariff mentions correlate strongly with these profiles, potentially shedding light on broader geopolitical and economic narratives at play in international trade.

# %%
# Normalize trade figures by population to create per capita values
# This will help in making the data suitable for k-means clustering

def normalize_by_population(df, columns, population_column):
    for column in columns:
        per_capita_column = column + ' Per Capita'
        df[per_capita_column] = df[column] / df[population_column]
    return df

# Normalize the selected numeric columns in the cleaned dataframe
columns_to_normalize = ['US 2024 Deficit', 'US 2024 Exports', 'US 2024 Imports (Customs Basis)']
normalized_df_cleaned = normalize_by_population(tariffs_with_population_df_cleaned, columns_to_normalize, 'Population')

# Display the first few rows to verify normalization
normalized_df_cleaned.head()  # Check the newly created per capita columns

# This step is essential for performing meaningful cluster analysis based on comparable scales of per capita trade values
# Completion of data normalization for clustering analysis.
# Out:
# C:\Users\David\AppData\Local\Temp\ipykernel_15936\945450802.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[per_capita_column] = df[column] / df[population_column]
# C:\Users\David\AppData\Local\Temp\ipykernel_15936\945450802.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[per_capita_column] = df[column] / df[population_column]
# C:\Users\David\AppData\Local\Temp\ipykernel_15936\945450802.py:7: SettingWithCopyWarning:
# ...

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# Select relevant columns to use for clustering
per_capita_columns = [col + ' Per Capita' for col in columns_to_normalize]
clustering_df = normalized_df_cleaned[['Country'] + per_capita_columns].dropna()

# Standardizing the data before clustering
scaler = StandardScaler()
X_scaled = scaler.fit_transform(clustering_df[per_capita_columns])

# Applying k-means clustering
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(X_scaled)

# Add cluster labels to the dataframe
clustering_df['Cluster'] = kmeans.labels_

# Display clustering result
print(clustering_df.head())  # Check the first few entries with their assigned cluster

# This completes the k-means clustering part of the analysis, finding profiles among countries based on per capita trade.
# Out:
#                Country  US 2024 Deficit Per Capita  \
# 0          Afghanistan               -2.677618e-07
# 1              Albania                4.879875e-06
# 3              Andorra                1.855150e-05
# 6  Antigua and Barbuda                5.893952e-03
# 8              Armenia                1.310642e-05
#
#    US 2024 Exports Per Capita  US 2024 Imports (Customs Basis) Per Capita  \
# 0                2.749986e-07                                5.451726e-07
# 1                5.160286e-05                                4.672298e-05
# 3                6.060156e-05                                4.205006e-05
# 6                6.148999e-03                                2.550474e-04
# 8                5.376308e-05                                4.065666e-05
#
#    Cluster
# 0        1
# 1        1
# 3        1
# 6        2
# 8        1

# %%
# Merge cluster labels back into the original cleaned dataset with qualitative columns

# Assuming the original cleaned dataset has qualitative columns such as 'Trump Tariffs Alleged', 'Trump Response'
merged_df_clean = pd.merge(tariffs_with_population_df_cleaned, clustering_df[['Country', 'Cluster']], on='Country')

# Display the first few rows to verify the merge
merged_df_clean.head()  # Verify that cluster labels are correctly merged with qualitative columns

# This setup will allow us to analyse how the cluster assignments align with qualitative data.
# Out:
#                Country  US 2024 Deficit  US 2024 Exports  \
# 0          Afghanistan            -11.1             11.4
# 1              Albania             13.4            141.7
# 2              Andorra              1.5              4.9
# 3  Antigua and Barbuda            550.0            573.8
# 4              Armenia             39.2            160.8
#
#    US 2024 Imports (Customs Basis) Trump Tariffs Alleged Trump Response  \
# 0                             22.6                   49%            25%
# 1                            128.3                   10%            10%
# 2                              3.4                   10%            10%
# 3                             23.8                   10%            10%
# 4                            121.6                   10%            10%
#
#    Population  US 2024 Deficit Per Capita  US 2024 Exports Per Capita  \
# 0  41454761.0               -2.677618e-07                2.749986e-07
# ...

# %%
# Analyze tariff responses by cluster

# Ensure `percentage_columns` is defined
percentage_columns = ['Trump Tariffs Alleged', 'Trump Response']

# Convert percentage columns to numeric for analysis
for column in percentage_columns:
    merged_df_clean[column] = merged_df_clean[column].str.rstrip('%').astype('float')

# Summarize data by cluster
cluster_summary = merged_df_clean.groupby('Cluster')[percentage_columns].agg(['mean', 'std'])
cluster_summary

# This summary will help determine if tariff mentions and responses have significant patterns across clusters.
# Out:
#         Trump Tariffs Alleged            Trump Response
#                          mean        std           mean        std
# Cluster
# 0                   10.000000   0.000000      10.000000   0.000000
# 1                   22.752809  23.679335      14.865169  10.017248
# 2                   10.000000   0.000000      10.000000   0.000000

# %%
import matplotlib.pyplot as plt

# Count the number of countries in each cluster
cluster_counts = clustering_df['Cluster'].value_counts().sort_index()

# Create a bar plot for the distribution of clusters
plt.figure(figsize=(8, 6))
plt.bar(cluster_counts.index, cluster_counts.values, color='skyblue')
plt.title('Number of Countries in Each Cluster')
plt.xlabel('Cluster')
plt.ylabel('Number of Countries')
plt.xticks(cluster_counts.index)
plt.show()  # Display the bar plot

# This visualizes how many countries fall into each cluster.

# %%
# Extract and display the list of countries in Cluster 0
countries_in_cluster_0 = clustering_df[clustering_df['Cluster'] == 0]['Country'].sort_values().tolist()
countries_in_cluster_0

# Displaying countries in the first cluster can reveal specific trade profiles or imbalances.
# Out:
# ['Gibraltar', 'Sint Maarten', 'Turks and Caicos Islands', 'Tuvalu (-)']

# %% [markdown]
# # Analysis of Clustering Model
#
# The k-means clustering process divided the countries into three distinct groups based on per-capita trade figures, which offer insights into the complex trade relationships each country maintains with the United States. This clustering helps identify how these groups can be differentiated based on tariff allegations or responses and economic profiles.
#
# ### Cluster Characteristics:
#
# **Cluster 0:**
# - **Example Country:** Gibraltar
# - **Characteristics:** Countries in this cluster are characterized by having the highest per capita deficits, suggesting significant trade imbalances or strategic economic connections with the United States. These countries possibly face large trade deficits concerning their GDP.
#
# **Cluster 1:**
# - **Example Country:** Albania
# - **Characteristics:** This cluster includes countries with the lowest per capita deficits. These nations typically have balanced trade relationships relative to their population size, with a greater equilibrium between imports and exports with the US.
#
# **Cluster 2:**
# - **Example Country:** Antigua and Barbuda
# - **Characteristics:** Countries in this cluster display moderate per capita deficits, indicating neither extreme surplus nor deficit. Their trading profile suggests a balanced trade pattern with capacity for strategic alterations, potentially leveraged for improved trade relations.
#
# Each of these clusters represents a unique profile of trade relationships between the US and its trading partners. Further exploration can offer insights into which trade partners are more sensitive to tariff policies based on their economic profiles and whether qualitative aspects such as tariff allegations correlate with these clusters.
#
# Now, let's visualize the clusters and see if we can get some insight

# %%
# Create a new column to classify countries by trade balance
# If deficit is negative, indicates imports exceed exports (importing more from the US)
# If deficit is positive, indicates exports exceed imports (exporting more to the US)

merged_df_clean['Trade_Balance'] = merged_df_clean['US 2024 Exports Per Capita'] - merged_df_clean['US 2024 Imports (Customs Basis) Per Capita']

# Classify based on trade balance
merged_df_clean['Trade_Relationship'] = ['Importing More' if x < 0 else 'Exporting More' for x in merged_df_clean['US 2024 Deficit']]

# Display the first few rows to check the new classification
merged_df_clean.head()  # Verify the 'Trade_Relationship' column is added and populated correctly.
# Out:
#                Country  US 2024 Deficit  US 2024 Exports  \
# 0          Afghanistan            -11.1             11.4
# 1              Albania             13.4            141.7
# 2              Andorra              1.5              4.9
# 3  Antigua and Barbuda            550.0            573.8
# 4              Armenia             39.2            160.8
#
#    US 2024 Imports (Customs Basis)  Trump Tariffs Alleged  Trump Response  \
# 0                             22.6                   49.0            25.0
# 1                            128.3                   10.0            10.0
# 2                              3.4                   10.0            10.0
# 3                             23.8                   10.0            10.0
# 4                            121.6                   10.0            10.0
#
#    Population  US 2024 Deficit Per Capita  US 2024 Exports Per Capita  \
# 0  41454761.0               -2.677618e-07                2.749986e-07
# ...

# %%
# Plot visualization
plt.figure(figsize=(12, 8))

# Scatter plot
sns.scatterplot(data=merged_df_clean, 
                x='US 2024 Deficit Per Capita', 
                y='Trump Tariffs Alleged', 
                hue='Trade_Relationship', 
                style='Cluster', 
                palette='deep',
                s=100)

# Setting plot details
plt.title('Tariffs vs Trade Deficit Per Capita by Trade Relationship')
plt.xlabel('US 2024 Deficit Per Capita')
plt.ylabel('Trump Tariffs Alleged (%)')
plt.legend(title='Trade Relationship', loc='best')
plt.grid(True)
plt.show()

# This visualization should help illuminate the correlation between trade balances, tariffs, and the response of different countries.

# %%
# Identify outliers based on the US 2024 Deficit
# Utilize the interquartile range to define outliers
Q1 = merged_df_clean['US 2024 Deficit'].quantile(0.25)
Q3 = merged_df_clean['US 2024 Deficit'].quantile(0.75)
IQR = Q3 - Q1

# Outliers are those outside 1.5*IQR from Q1 and Q3
outliers_condition = (merged_df_clean['US 2024 Deficit'] < (Q1 - 1.5 * IQR)) | (merged_df_clean['US 2024 Deficit'] > (Q3 + 1.5 * IQR))
deficit_outliers_df = merged_df_clean[outliers_condition]

deficit_outliers_summary = deficit_outliers_df[['Country', 'US 2024 Deficit', 'Trump Tariffs Alleged', 'Trump Response']]

deficit_outliers_summary  # Displays outliers with relevant details.
# Out:
#                      Country  US 2024 Deficit  Trump Tariffs Alleged  \
# 3        Antigua and Barbuda            550.0                   10.0
# 5                      Aruba            714.8                   10.0
# 7                   Barbados            724.0                   10.0
# 9                     Belize            509.3                   10.0
# 11                   Bermuda            517.1                   10.0
# 15                  Botswana           -300.8                   74.0
# 25                      Cuba            581.6                   10.0
# 26                   Curacao            791.6                   10.0
# 32             Faroe Islands           -248.1                   99.0
# 37                 Gibraltar            650.2                   10.0
# 47                   Lesotho           -234.5                   99.0
# 50                Madagascar           -679.8                   93.0
# 60                  Mongolia            369.6                   10.0
# ...

# %%
# Visualize outliers using a bar plot
plt.figure(figsize=(12, 8))
outlier_countries = deficit_outliers_summary['Country']

deficit_values = deficit_outliers_summary['US 2024 Deficit']

# Plotting
sns.barplot(x=deficit_values, y=outlier_countries, palette='muted')

# Overlay text with tariff details, position above the bars
for i, (deficit, tariff, response) in enumerate(zip(deficit_values, deficit_outliers_summary['Trump Tariffs Alleged'], deficit_outliers_summary['Trump Response'])):
    plt.text(deficit, i, f'Tariff: {tariff}%, Response: {response}%',
             va='bottom', ha='left', color='black', fontsize=10, 
             transform=plt.gca().transData)

# Setting plot details
plt.title('Trade Deficit and Tariff Details for Outlier Countries')
plt.xlabel('Trade Deficit (Million USD)')
plt.ylabel('Country')
plt.grid(True)
plt.show()

# This visualization displays trade deficits of outlier countries with trade details as annotations above each bar.
# Out:
# C:\Users\David\AppData\Local\Temp\ipykernel_15936\1047318330.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=deficit_values, y=outlier_countries, palette='muted')

# %% [markdown]
# # Analysis of Trade Relationships and Tariff Impacts
#
# ### Cluster 1: High Per Capita Deficits in Favor of Other Countries
# - **Trade Relationship**: This cluster is characterized by countries having significantly higher per capita trade deficits with the United States. These countries often import more from the U.S. than they export.
# - **Political Relationship**: Countries in this cluster that do not have trade deficits with the United States but still suffer high tariffs may have other factors in their relationship with the U.S. that the Trump administration hopes to influence through tariffs.
# - **Tariff Impact**: Given these countries' dependency on U.S. imports, the imposition of tariffs may lead to increased costs for consumers and businesses within these countries, potentially straining their economies. However, these countries' substantial trade imbalances imply potential leverage for the U.S. in trade negotiations.
#
# ### Cluster 0: High Per Capita Deficits in Favor of U.S.
# - **Trade Relationship**: Countries in this cluster exhibit high deficits that favor the U.S.
# - **Tariff Impact**: Tariffs imposed on this cluster are likely to have limited economic impact as these countries export very little to the United States.
#
# ### Cluster 2: Moderate Per Capita Deficits
# - **Trade Relationship**: This cluster is defined by countries with moderate per capita deficits in favor of U.S. or balanced trade relations.
# - **Tariff Impact**: The imposition of tariffs could potentially alter their import-export equilibrium. Increased tariffs might strain their economies if U.S. goods are critical, or could influence them to enhance their domestic industries by pivoting away from U.S. imports.
#
# Overall, while tariffs always risk retaliatory actions or economic disruption, strategic implementation considering each cluster's profile could potentially enhance U.S. trade positions or economic influence without significantly affecting overall relations. Further detailed analysis should consider specific country-level contexts within each group to optimize policy decisions.
